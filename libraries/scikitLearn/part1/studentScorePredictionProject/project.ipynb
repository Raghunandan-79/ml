# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# %%
data = pd.read_csv("student.csv")

x = data[['Hours']]
y = data['Score']

model = LinearRegression()
model.fit(x, y)

predicted_score = model.predict(x)

# %%
# evaluation
mae = mean_absolute_error(y, predicted_score)
mse = mean_squared_error(y, predicted_score)
rmse = np.sqrt(mse)

# show results
print(f"Mean Absolute ERROR (MAE): {mae}")
print(f"Mean Squared ERROR (MSE): {mse}")
print(f"Root Mean Squared ERROR (RMSE): {rmse}")
# Out:
# Mean Absolute ERROR (MAE): 0.6666666666666643
# Mean Squared ERROR (MSE): 0.6285714285714282
# Root Mean Squared ERROR (RMSE): 0.7928249671720916

# %%
new_prediction = model.predict([[7]])
print("Predicted Score for 7 hour", new_prediction)
# Out:
# Predicted Score for 7 hour [86.4]
# /home/raghu/Documents/ml/libraries/.venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
